# %%
#импортируем библиотеки sqlite3 и pandas
import sqlite3
import pandas as pd

# %%
#устанавливаем pandas_profiling
# !pip install pandas_profiling[notebook]

# %%
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %%
#импортируем pandas_profiling
import pandas_profiling
# Out:
# <ipython-input-32-7e503e39c0ae>:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %%
#готовим датафрейм 'area'с данными
df1=pd.read_excel('/content/area.xlsx')

# %%
df1
# Out:
#    area_id        area_name
# 0        1           Москва
# 1        2  Санкт-Петербург
# 2        3     Екатеринбург
# 3       88           Казань
# 4       26          Воронеж
# 5        4      Новосибирск

# %%
#проводим анализ-отчет датафрейма 'area' c помощью pandas_profiling
df1.profile_report()

# %%
#готовим датафрейм 'employer' с данными
df2=pd.read_excel('/content/employer.xlsx')

# %%
df2
# Out:
#      employer_id                                      employer_name  \
# 0      3737733.0                                              #IZUM
# 1      1066298.0                                             FONBET
# 2      5560348.0                                         Ameli Soul
# 3      4126352.0                           Щербин Алексей Сергеевич
# 4      1643001.0                                  UNICA engineering
# ..           ...                                                ...
# 118    1863957.0                                              Attek
# 119     738493.0  Санкт-Петербургская Международная Товарно-сырь...
# 120    4482374.0                                         Медиапоинт
# 121    4151200.0                                    Метр квадратный
# 122      53879.0                                           ITooLabs
#
#                        employer_url
# 0    https://hh.ru/employer/3737733
# 1    https://hh.ru/employer/1066298
# 2    https://hh.ru/employer/5560348
# 3    https://hh.ru/employer/4126352
# 4    https://hh.ru/employer/1643001
# ..                              ...
# 118  https://hh.ru/employer/1863957
# 119   https://hh.ru/employer/738493
# 120  https://hh.ru/employer/4482374
# 121  https://hh.ru/employer/4151200
# 122    https://hh.ru/employer/53879
#
# [123 rows x 3 columns]

# %%
#проводим анализ-отчет датафрейма 'employer' с помощью pandas_profiling
df2.profile_report()

# %%
# готовим датафрейм 'vacancies_data_for_analysis' с данными
df3=pd.read_excel('/content/vacancies_data_for_analysis.xlsx')

# %%
df3
# Out:
#            id  premium relations  \
# 0    81870177    False        []
# 1    81412273    False        []
# 2    82220060    False        []
# 3    81241165    False        []
# 4    81243565    False        []
# ..        ...      ...       ...
# 169  81659114    False        []
# 170  81088795    False        []
# 171  79847584    False        []
# 172  80377291    False        []
# 173  81832493    False        []
#
#                                                   name  insider_interview  \
# 0                               Аналитик данных стажёр                NaN
# 1                                      Аналитик данных                NaN
# 2             Аналитик данных (удаленно, онлайн-школа)                NaN
# 3              Аналитик данных / Data Analyst (Junior)                NaN
# 4                                      Аналитик данных                NaN
# ..                                                 ...                ...
# 169                           Team Lead Ad Hoc Analyst                NaN
# 170                            Аналитик больших данных                NaN
# 171                                        BI-аналитик                NaN
# 172                             Системный аналитик DWH                NaN
# 173  Senior Product Data Analyst / Ведущий продукто...                NaN
#
#      response_letter_required  salary  allow_messages  department  contacts  \
# 0                       False     NaN            True         NaN       NaN
# 1                       False     NaN            True         NaN       NaN
# 2                       False     NaN            True         NaN       NaN
# 3                       False     NaN           False         NaN       NaN
# 4                       False     NaN            True         NaN       NaN
# ..                        ...     ...             ...         ...       ...
# 169                     False     NaN            True         NaN       NaN
# 170                     False     NaN            True         NaN       NaN
# 171                     False     NaN            True         NaN       NaN
# 172                     False     NaN           False         NaN       NaN
# 173                     False     NaN            True         NaN       NaN
#
#      ... salary.from salary.to  salary.currency salary.gross  \
# 0    ...         NaN       NaN              NaN          NaN
# 1    ...         NaN       NaN              NaN          NaN
# 2    ...    110000.0       NaN              RUR          0.0
# 3    ...     50000.0   70000.0              RUR          0.0
# 4    ...         NaN       NaN              NaN          NaN
# ..   ...         ...       ...              ...          ...
# 169  ...         NaN       NaN              NaN          NaN
# 170  ...         NaN       NaN              NaN          NaN
# 171  ...         NaN       NaN              NaN          NaN
# 172  ...         NaN       NaN              NaN          NaN
# 173  ...         NaN       NaN              NaN          NaN
#
#      employer.logo_urls  department.id            department.name  \
# 0                   NaN            NaN                        NaN
# 1                   NaN            NaN                        NaN
# 2                   NaN            NaN                        NaN
# 3                   NaN            NaN                        NaN
# 4                   NaN            NaN                        NaN
# ..                  ...            ...                        ...
# 169                 NaN            NaN                        NaN
# 170                 NaN    bil-4934-it  билайн: ИТ, Data, Digital
# 171                 NaN            NaN                        NaN
# 172                 NaN            NaN                        NaN
# 173                 NaN            NaN                        NaN
#
#      insider_interview.id insider_interview.url test.required
# 0                     NaN                   NaN           NaN
# 1                     NaN                   NaN           NaN
# 2                     NaN                   NaN           NaN
# 3                     NaN                   NaN           NaN
# 4                     NaN                   NaN           NaN
# ..                    ...                   ...           ...
# 169                   NaN                   NaN           NaN
# 170                   NaN                   NaN           NaN
# 171                   NaN                   NaN           NaN
# 172                   NaN                   NaN           NaN
# 173                   NaN                   NaN           NaN
#
# [174 rows x 88 columns]

# %%
# проводим анализ-отчет датафрейма 'vacancies_data_for_analysis' с помощью pandas_profiling
df3.profile_report()

# %%
# удаление дубликатов из датафрейма 'vacancies_data_for_analysis'
df3 = df3.drop_duplicates()

# %%
df3
# Out:
#            id  premium relations  \
# 0    81870177    False        []
# 1    81412273    False        []
# 2    82220060    False        []
# 3    81241165    False        []
# 4    81243565    False        []
# ..        ...      ...       ...
# 169  81659114    False        []
# 170  81088795    False        []
# 171  79847584    False        []
# 172  80377291    False        []
# 173  81832493    False        []
#
#                                                   name  insider_interview  \
# 0                               Аналитик данных стажёр                NaN
# 1                                      Аналитик данных                NaN
# 2             Аналитик данных (удаленно, онлайн-школа)                NaN
# 3              Аналитик данных / Data Analyst (Junior)                NaN
# 4                                      Аналитик данных                NaN
# ..                                                 ...                ...
# 169                           Team Lead Ad Hoc Analyst                NaN
# 170                            Аналитик больших данных                NaN
# 171                                        BI-аналитик                NaN
# 172                             Системный аналитик DWH                NaN
# 173  Senior Product Data Analyst / Ведущий продукто...                NaN
#
#      response_letter_required  salary  allow_messages  department  contacts  \
# 0                       False     NaN            True         NaN       NaN
# 1                       False     NaN            True         NaN       NaN
# 2                       False     NaN            True         NaN       NaN
# 3                       False     NaN           False         NaN       NaN
# 4                       False     NaN            True         NaN       NaN
# ..                        ...     ...             ...         ...       ...
# 169                     False     NaN            True         NaN       NaN
# 170                     False     NaN            True         NaN       NaN
# 171                     False     NaN            True         NaN       NaN
# 172                     False     NaN           False         NaN       NaN
# 173                     False     NaN            True         NaN       NaN
#
#      ... salary.from salary.to  salary.currency salary.gross  \
# 0    ...         NaN       NaN              NaN          NaN
# 1    ...         NaN       NaN              NaN          NaN
# 2    ...    110000.0       NaN              RUR          0.0
# 3    ...     50000.0   70000.0              RUR          0.0
# 4    ...         NaN       NaN              NaN          NaN
# ..   ...         ...       ...              ...          ...
# 169  ...         NaN       NaN              NaN          NaN
# 170  ...         NaN       NaN              NaN          NaN
# 171  ...         NaN       NaN              NaN          NaN
# 172  ...         NaN       NaN              NaN          NaN
# 173  ...         NaN       NaN              NaN          NaN
#
#      employer.logo_urls  department.id            department.name  \
# 0                   NaN            NaN                        NaN
# 1                   NaN            NaN                        NaN
# 2                   NaN            NaN                        NaN
# 3                   NaN            NaN                        NaN
# 4                   NaN            NaN                        NaN
# ..                  ...            ...                        ...
# 169                 NaN            NaN                        NaN
# 170                 NaN    bil-4934-it  билайн: ИТ, Data, Digital
# 171                 NaN            NaN                        NaN
# 172                 NaN            NaN                        NaN
# 173                 NaN            NaN                        NaN
#
#      insider_interview.id insider_interview.url test.required
# 0                     NaN                   NaN           NaN
# 1                     NaN                   NaN           NaN
# 2                     NaN                   NaN           NaN
# 3                     NaN                   NaN           NaN
# 4                     NaN                   NaN           NaN
# ..                    ...                   ...           ...
# 169                   NaN                   NaN           NaN
# 170                   NaN                   NaN           NaN
# 171                   NaN                   NaN           NaN
# 172                   NaN                   NaN           NaN
# 173                   NaN                   NaN           NaN
#
# [158 rows x 88 columns]

# %%
# Определение нужных столбцов и сохранение результатов
df3 = df3[['id', 'name', 'area.id','address.metro.station_name','salary.from','salary.to','address.raw','experience.name','schedule.name','employment.name','employer.id','alternate_url','created_at']]

# %%
df3
# Out:
#            id                                               name  area.id  \
# 0    81870177                             Аналитик данных стажёр        1
# 1    81412273                                    Аналитик данных        1
# 2    82220060           Аналитик данных (удаленно, онлайн-школа)        1
# 3    81241165            Аналитик данных / Data Analyst (Junior)        1
# 4    81243565                                    Аналитик данных        1
# ..        ...                                                ...      ...
# 169  81659114                           Team Lead Ad Hoc Analyst        1
# 170  81088795                            Аналитик больших данных        1
# 171  79847584                                        BI-аналитик        1
# 172  80377291                             Системный аналитик DWH        1
# 173  81832493  Senior Product Data Analyst / Ведущий продукто...        1
#
#     address.metro.station_name  salary.from  salary.to  \
# 0       Преображенская площадь          NaN        NaN
# 1                          NaN          NaN        NaN
# 2                          NaN     110000.0        NaN
# 3                          NaN      50000.0    70000.0
# 4                          NaN          NaN        NaN
# ..                         ...          ...        ...
# 169                        NaN          NaN        NaN
# 170                        NaN          NaN        NaN
# 171                        NaN          NaN        NaN
# 172                        NaN          NaN        NaN
# 173                        NaN          NaN        NaN
#
#                               address.raw     experience.name  \
# 0    Москва, Электрозаводская улица, 29с1           Нет опыта
# 1        Москва, Николоямская улица, 24с1  От 1 года до 3 лет
# 2                                     NaN  От 1 года до 3 лет
# 3                                     NaN           Нет опыта
# 4         Москва, Трифоновский тупик, 3с2           Нет опыта
# ..                                    ...                 ...
# 169                                   NaN       От 3 до 6 лет
# 170                                   NaN       От 3 до 6 лет
# 171                                   NaN       От 3 до 6 лет
# 172                                   NaN       От 3 до 6 лет
# 173                                   NaN       От 3 до 6 лет
#
#         schedule.name   employment.name  employer.id  \
# 0         Полный день        Стажировка    3737733.0
# 1         Полный день  Полная занятость    1066298.0
# 2    Удаленная работа  Полная занятость    5560348.0
# 3    Удаленная работа  Полная занятость    4126352.0
# 4         Полный день  Полная занятость    1643001.0
# ..                ...               ...          ...
# 169       Полный день  Полная занятость    4482374.0
# 170  Удаленная работа  Полная занятость       4934.0
# 171       Полный день  Полная занятость    4151200.0
# 172       Полный день  Полная занятость      78638.0
# 173  Удаленная работа  Полная занятость      53879.0
#
#                       alternate_url                created_at
# 0    https://hh.ru/vacancy/81870177  2023-06-19T22:28:08+0300
# 1    https://hh.ru/vacancy/81412273  2023-06-01T13:35:08+0300
# 2    https://hh.ru/vacancy/82220060  2023-06-21T10:20:27+0300
# 3    https://hh.ru/vacancy/81241165  2023-06-22T18:37:11+0300
# 4    https://hh.ru/vacancy/81243565  2023-05-29T14:44:45+0300
# ..                              ...                       ...
# 169  https://hh.ru/vacancy/81659114  2023-06-22T14:03:23+0300
# 170  https://hh.ru/vacancy/81088795  2023-06-22T11:55:14+0300
# 171  https://hh.ru/vacancy/79847584  2023-06-22T13:37:00+0300
# 172  https://hh.ru/vacancy/80377291  2023-06-22T15:39:48+0300
# 173  https://hh.ru/vacancy/81832493  2023-06-22T11:11:08+0300
#
# [158 rows x 13 columns]

# %%
df3.columns
# Out:
# Index(['id', 'name', 'area.id', 'address.metro.station_name', 'salary.from',
#        'salary.to', 'address.raw', 'experience.name', 'schedule.name',
#        'employment.name', 'employer.id', 'alternate_url', 'created_at'],
#       dtype='object')

# %%
# повторный анализ-отчет датафрейма 'vacancies_data_for_analysis' с помощью pandas_profiling
df3.profile_report()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v0.0.dev0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-08-23 14:36:27.175369&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
#  *//*! normalize.css v3.0.3 | MIT License | github.com/necolas/normalize.css */html{font-family:sans-serif;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}body{margin:0}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section,summary{display:block}audio,canvas,progress,video{display:inline-block;vertical-align:baseline}audio:not([controls]){display:none;height:0}[hidden],template{display:none}a{background-color:transparent}a:active,a:hover{outline:0}abbr[title]{border-bottom:1px dotted}b,strong{font-weight:700}dfn{font-style:italic}h1{margin:.67em 0;font-size:2em}mark{color:#000;background:#ff0}small{font-size:80%}sub,sup{position:relative;font-size:75%;line-height:0;vertical-align:baseline}sup{top:-.5em}sub{bottom:-.25em}img{border:0}svg:not(:root){overflow:hidden}figure{margin:1em 40px}hr{height:0;-webkit-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box}pre{overflow:auto}code,kbd,pre,samp{font-family:monospace,monospace;font-size:1em}button,input,optgroup,select,textarea{margin:0;font:inherit;color:inherit}button{overflow:visible}button,select{text-transform:none}button,html input[type=button],input[type=reset],input[type=submit]{-webkit-appearance:button;cursor:pointer}button[disabled],html input[disabled]{cursor:default}button::-moz-focus-inner,input::-moz-focus-inner{padding:0;border:0}input{line-height:normal}input[type=checkbox],input[type=radio]{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box;padding:0}input[type=number]::-webkit-inner-spin-button,input[type=number]::-webkit-outer-spin-button{height:auto}input[type=search]{-webkit-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box;-webkit-appearance:textfield}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration{-webkit-appearance:none}fieldset{padding:.35em .625em .75em;margin:0 2px;border:1px solid silver}legend{padding:0;border:0}textarea{overflow:auto}optgroup{font-weight:700}table{border-spacing:0;border-collapse:collapse}td,th{padding:0}/*! Source: https://github.com/h5bp/html5-boilerplate/blob/master/src/css/main.css */@media print{*,:after,:before{color:#000!important;text-shadow:none!important;background:0 0!important;-webkit-box-shadow:none!important;box-shadow:none!important}a,a:visited{text-decoration:underline}a[href]:after{content:&quot; (&quot; attr(href) &quot;)&quot;}abbr[title]:after{content:&quot; (&quot; attr(title) &quot;)&quot;}a[href^=&quot;javascript:&quot;]:after,a[href^=&quot;#&quot;]:after{content:&quot;&quot;}blockquote,pre{border:1px solid #999;page-break-inside:avoid}thead{display:table-header-group}img,tr{page-break-inside:avoid}img{max-width:100%!important}h2,h3,p{orphans:3;widows:3}h2,h3{page-break-after:avoid}.navbar{display:none}.btn&gt;.caret,.dropup&gt;.btn&gt;.caret{border-top-color:#000!important}.label{border:1px solid #000}.table{border-collapse:collapse!important}.table td,.table th{background-color:#fff!important}.table-bordered td,.table-bordered th{border:1px solid #ddd!important}}@font-face{font-family:&#x27;Glyphicons Halflings&#x27;;src:url(../fonts/glyphicons-halflings-regular.eot);src:url(../fonts/glyphicons-halflings-regular.eot?#iefix) format(&#x27;embedded-opentype&#x27;),url(../fonts/glyphicons-halflings-regular.woff2) format(&#x27;woff2&#x27;),url(../fonts/glyphicons-halflings-regular.woff) format(&#x27;woff&#x27;),url(../fonts/glyphicons-halflings-regular.ttf) format(&#x27;truetype&#x27;),url(../fonts/glyphicons-halflings-regular.svg#glyphicons_halflingsregular) format(&#x27;svg&#x27;)}.glyphicon{position:relative;top:1px;display:inline-block;font-family:&#x27;Glyphicons Halflings&#x27;;font-style:normal;font-weight:400;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.glyphicon-asterisk:before{content:&quot;\002a&quot;}.glyphicon-plus:before{content:&quot;\002b&quot;}.glyphicon-eur:before,.glyphicon-euro:before{content:&quot;\20 ...

# %%
# подключение к базе данных, создание новой базы  'vacancies_data_analysis.db'
con=sqlite3.connect('vacancies_data_analуsis.db', timeout=10)
cur=con.cursor()

# %%
# загружаем таблицу 'area"  в базу данных
df1.to_sql(con=con, name='area', index=False)
# Out:
# 6

# %%
# загружаем таблицу 'employer' в базу данных
df2.to_sql(con=con, name='employer', index=False)
# Out:
# 123

# %%
# загружаем таблицу 'vacancies' в базу данных
df3.to_sql(con=con, name='vacancies', index=False)
# Out:
# 158
